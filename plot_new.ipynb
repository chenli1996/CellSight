# %%
# plot figure
from re import M
import matplotlib.pyplot as plt
import numpy as np
# Loss_list_LR_90 = [0.0044,0.007,0.0129,0.020]
LR = [0.0014,0.0043,0.0102,0.0173,0.0229]
TLR = [0.0006,0.0028,0.0085,0.0158,0.0223]
MLP = [np.nan,0.0036,0.0093,0.0137,0.0232]
LSTM = []
# G1 = [0.00246,0.00541,0.0097,0.0124,0.0138]
T1 = [np.nan,0.004,0.01,0.011,0.012]
# plot graph_mse and tlr_mse, with dash line and dot mark on each point
# x axis is 1,10,30,60,150
x = [1,10,30,60,150]

# exclude first point
x = x[1:]
LR = LR[1:]
TLR = TLR[1:]
G1 = G1[1:]
T1 = T1[1:]
MLP = MLP[1:]

# # convert to R square 
# def convert_to_R_square(loss_list):
#     return 1 - np.array(loss_list)/0.043
# LR = convert_to_R_square(LR)
# TLR = convert_to_R_square(TLR)
# MLP = convert_to_R_square(MLP)

# G1 = convert_to_R_square(G1)
# T1 = convert_to_R_square(T1)


plt.plot(x, T1, label='Ours', linestyle='--', marker='o')
# plt.plot(x, G1, label='GAT-based', linestyle='--', marker='o')
plt.plot(x, LR, label='LR', linestyle='--', marker='o')
plt.plot(x, TLR, label='TLR', linestyle='--', marker='o')
plt.plot(x, MLP, label='MLP', linestyle='--', marker='o')


plt.legend()
plt.xlabel('Prediction horizon/frame')
plt.ylabel('mse')
# plt.title('mse loss for in-Fov prediction')
# plt.savefig('../result/R_square_score.png')
plt.show()

# %%
# plot figure
from re import M
import matplotlib.pyplot as plt
import numpy as np
# Loss_list_LR_90 = [0.0044,0.007,0.0129,0.020]
# LR = [0.0014,0.0043,0.0102,0.0173,0.0229]
# TLR = [0.0006,0.0028,0.0085,0.0158,0.0223]
# MLP = [np.nan,0.0249,np.nan,0.028,np.nan]
# G1 = [0.00246,0.00541,0.0097,0.0124,0.0138]
# T1 = [np.nan,0.004,0.01,0.011,0.012]
# plot graph_mse and tlr_mse, with dash line and dot mark on each point
# x axis is 1,10,30,60,150
x = [1,10,30,60,150]
# Loss_list_LR_90 = [0.0044,0.007,0.0129,0.020]
LR = [0.0014,0.0043,0.0102,0.0173,0.0229]
TLR = [0.0006,0.0028,0.0085,0.0158,0.0223]
MLP = [np.nan,0.0036,0.0093,0.0137,0.0232]
# G1 = [0.00246,0.00541,0.0097,0.0124,0.0138]
T1 = [np.nan,0.004,0.01,0.011,0.012]


# # convert to R square 
def convert_to_R_square(loss_list):
    return 1 - np.array(loss_list)/0.043
LR = convert_to_R_square(LR)
TLR = convert_to_R_square(TLR)
MLP = convert_to_R_square(MLP)

G1 = convert_to_R_square(G1)
T1 = convert_to_R_square(T1)


plt.plot(x, T1, label='Ours', linestyle='--', marker='o')
# plt.plot(x, G1, label='GAT-based', linestyle='--', marker='o')
plt.plot(x, LR, label='LR', linestyle='--', marker='o')
plt.plot(x, TLR, label='TLR', linestyle='--', marker='o')
plt.plot(x, MLP, label='MLP', linestyle='--', marker='o')


plt.legend()
plt.xlabel('Prediction horizon/frame')
plt.ylabel('R^2')
# plt.title('mse loss for in-Fov prediction')
# plt.savefig('../result/R_square_score.png')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
start = 0
x = [1,10, 30, 60, 150][start:]
LR = [0.0014, 0.0043, 0.0102, 0.0173, 0.0229][start:]
TLR = [0.0006, 0.0028, 0.0085, 0.0158, 0.0223][start:]
MLP = [np.nan, 0.0036, 0.0093, 0.0137, 0.0232][start:]
T1 = [np.nan, 0.004, 0.01, 0.011, 0.012][start:]
LSTM = [0.0004,0.0026,0.0083,0.0126,0.0154][start:]

# Convert to R^2
def convert_to_R_square(loss_list):
    return 1 - np.array(loss_list) / 0.043

# LR = convert_to_R_square(LR)
# TLR = convert_to_R_square(TLR)
# MLP = convert_to_R_square(MLP)
# T1 = convert_to_R_square(T1)

# Plotting with enhanced visualization
plt.figure(figsize=(10, 6))

plt.plot(x, T1, label='Ours', linestyle='--', marker='o', markersize=8)
plt.plot(x, LR, label='LR', linestyle='--', marker='s', markersize=8)
plt.plot(x, TLR, label='TLR', linestyle='--', marker='D', markersize=8)
plt.plot(x, MLP, label='M-MLP', linestyle='--', marker='^', markersize=8)
plt.plot(x, LSTM, label='LSTM', linestyle='--', marker='x', markersize=8)

# Enlarging fonts
plt.legend(title="Method", fontsize=16)
plt.xlabel('Prediction Horizon (frames)', fontsize=18)
plt.ylabel('MSE', fontsize=18)
plt.grid(True, linestyle='--', alpha=0.7)
plt.xticks(x, fontsize=14)
plt.yticks(fontsize=14)
plt.title('MSE Loss for Cell Visibility Prediction', fontsize=20)
# plt.ylim(0, 1)

plt.show()

# %%
# # plot figure
# import matplotlib.pyplot as plt
# import numpy as np
# # plot figure
# graph_mse = [0.0008
# ,0.016
# ,0.050
# ,0.072
# ,0.079
# ,0.085
# ]
# graph_mae = [0.010
# ,0.050
# ,0.119
# ,0.163
# ,0.184
# ,0.205
# ]
# tlr_mse = [0.004
# ,0.026
# ,0.079
# ,0.138
# ,0.1755
# ,0.195
# ]
# tlr_mae = [0.016
# ,0.053
# ,0.116
# ,0.178
# ,0.217
# ,0.238
# ]


mlp = [0.0280,0.0735,0.1080,0.1818]
tlr = [0.026
,0.079
,0.138
,0.195
]
our = [
0.016
,0.050
,0.072
,0.085
]
lr = [0.0422,0.0966,0.156,0.192]
# plot graph_mse and tlr_mse, with dash line and dot mark on each point
# x axis is 1,10,30,60,90,150
# x = [1,10,30,60,90,150]
x = [10,30,60,150]


# # Convert to R^2
# def convert_to_R_square(loss_list):
#     return 1 - np.array(loss_list) / 0.043

# lr = convert_to_R_square(lr)
# our = convert_to_R_square(our)
# tlr = convert_to_R_square(tlr)
# mlp = convert_to_R_square(mlp)

plt.plot(x, our, label='graph_mse', linestyle='--', marker='o')
plt.plot(x, tlr, label='tlr_mse', linestyle='--', marker='o')
plt.plot(x, mlp, label='mlp', linestyle='--', marker='o')
plt.plot(x, lr, label='lr', linestyle='--', marker='o')

plt.legend()
plt.xlabel('prediction horizon')
plt.ylabel('mse')
plt.title('mse loss for in-Fov prediction')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x = [10, 30, 60, 150]
mlp = [0.0280, 0.0735, 0.1080, 0.1818]
tlr = [0.026, 0.079, 0.138, 0.195]
our = [0.016, 0.050, 0.072, 0.085]
lr = [0.0422, 0.0966, 0.156, 0.192]
lstm = [0.1062]

# Plotting with enhanced visualization
plt.figure(figsize=(10, 6))

plt.plot(x, our, label='Ours', linestyle='--', marker='o', markersize=8)
plt.plot(x, lr, label='LR', linestyle='--', marker='s', markersize=8)
plt.plot(x, tlr, label='TLR', linestyle='--', marker='D', markersize=8)
plt.plot(x, mlp, label='MLP', linestyle='--', marker='^', markersize=8)




plt.legend(title="Method", fontsize=16)
plt.xlabel('Prediction Horizon (frames)', fontsize=18)
plt.ylabel('MSE', fontsize=18)
# plt.title('MSE Loss for  Prediction Across Different Horizons', fontsize=16)
plt.grid(True, linestyle='--', alpha=0.7)
plt.xticks(x, fontsize=14)
plt.yticks(fontsize=14)
plt.ylim(0, 0.22)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x = [1,10, 30, 60, 150]
x = [33,333,1000,2000,5000]
# mlp = [0.0280, 0.0735, 0.1080, 0.1818]
# tlr = [0.026, 0.079, 0.138, 0.195]
our = [0.00075,0.0058, 0.0127, 0.0158, 0.0182]
# lr = [0.0422, 0.0966, 0.156, 0.192]
lstm = [0.00036,0.0063, 0.0194, 0.0265, 0.0288]

# Plotting with enhanced visualization
plt.figure(figsize=(10, 6))

plt.plot(x, our, label='Ours', linestyle='--', marker='o', markersize=8)
# plt.plot(x, lr, label='LR', linestyle='--', marker='s', markersize=8)
# plt.plot(x, tlr, label='TLR', linestyle='--', marker='D', markersize=8)
# plt.plot(x, mlp, label='MLP', linestyle='--', marker='^', markersize=8)
plt.plot(x, lstm, label='LSTM', linestyle='--', marker='^', markersize=8)




plt.legend(title="Method", fontsize=16)
plt.xlabel('Prediction Horizon (ms)', fontsize=18)
plt.ylabel('MSE', fontsize=18)
# plt.title('MSE Loss for  Prediction Across Different Horizons', fontsize=16)
plt.grid(True, linestyle='--', alpha=0.7)
plt.xticks(x, fontsize=14)
plt.yticks(fontsize=14)
# plt.ylim(0, 0.22)
plt.title('MSE Loss for Cell Visibility Prediction', fontsize=20)

plt.show()
